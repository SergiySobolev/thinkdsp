# %%
from __future__ import print_function, division

# %matplotlib inline

import sbkdsp
import thinkplot

import numpy as np

#import warnings
#warnings.filterwarnings('ignore')

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display

# %%
cos_sig = sbkdsp.cosSignal(freq=440, amp=1.0, offset=0)
sin_sig = sbkdsp.sinSignal(freq=880, amp=0.5, offset=0)

# %%
cos_sig.plot()

# %%
sin_sig.plot(periods=5)

# %%
mix = sin_sig + cos_sig
mix.plot()

# %%
wave = mix.make_wave(duration=1.5, start=0, framerate=11025)
from IPython.display import Audio
audio = Audio(data=wave.ys, rate=wave.framerate)
audio
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
period = mix.period
segment = wave.segment(start=0, duration=period*7)
segment.plot()

# %%
wave.normalize()
wave.apodize()
wave.plot()

# %%
wave = sbkdsp.read_wave('input/sound/92002__jcveliz__violin-origional.wav')

# %%
spectrum = wave.make_spectrum()
spectrum.plot()
thinkplot.config(xlabel='Frequency (Hz)')

# %%
spectrum.low_pass(cutoff=600, factor=0.01)

# %%
spectrum.plot()
