# %%
from __future__ import print_function, division

# %matplotlib inline

from com.sbk.converter.converter import signal_to_wave
import com.sbk.func.trigonometry.trigonometry as trigonometry
from IPython.display import display

# %%
frame_rate = 10000
freq_1 = 450
cos_signal_1 = trigonometry.cos_signal(freq_1)
duration = cos_signal_1.period*5
cos_wave_1 = signal_to_wave(signal=cos_signal_1, duration=duration, frame_rate=frame_rate)
cos_wave_1.plot()

# %%
freq_2 = 5500
cos_signal_2 = trigonometry.cos_signal(freq_2)
cos_wave_2 = signal_to_wave(signal=cos_signal_2, duration=duration, frame_rate=frame_rate)
cos_wave_2.plot()
